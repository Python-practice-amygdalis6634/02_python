# %%
class Person:
    nationality = 'Korea'

    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greeting(self):

# %%
# Out:
# <__main__.Person object at 0x00000226FA403740> <class '__main__.Person'>
# hong.name:  홍길동
# hong.age:  20
# hong.nationality:  Korea
# <__main__.Person object at 0x00000226FA41B8F0> <class '__main__.Person'>
# lee.name:  이순신
# lee.age:  33
# lee.nationality:  Korea

# %%
class Person:
    nationality = "Korea"

    def __init__(self, name, age):

        self.name = name
        self.age = age

    def greeting(self):
        print(f"안녕하세요. 제 이름은 {self.name}이고, 나이는 {self.age}입니다.")

hong = Person('홍길동', 30)

print(hong.name)
print(hong.age)
print(hong.nationality)

lee = Person('이순신', 33)

hong.greeting()

Person.greeting(hong)
# Out:
# 홍길동
# 30
# Korea
# 안녕하세요. 제 이름은 홍길동이고, 나이는 30입니다.
# 안녕하세요. 제 이름은 홍길동이고, 나이는 30입니다.
